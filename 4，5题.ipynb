# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from pylab import *
from datetime import *
from time import time
import mpl_finance as mpf
import seaborn
from jaqs_fxdayu.data.dataservice import LocalDataService
from jaqs_fxdayu.data.hf_dataview import HFDataView
import warnings
warnings.filterwarnings('ignore')

ds = LocalDataService()

# %%
# 获取数据
start = time()
path = r'./min_data/VnTrader_1Min_Db'
props = {'fields': 'open,high,low,close,volume','symbol': 'BTCUSDT:binance', 'freq': '4H',
         'start_date':20180601000000}

# %%
Time_dict = ds.bar_reader(path,props)

# %%
Time_dict
# Out:
#               symbol            datetime      trade_date    close     high  \
# 0    BTCUSDT:binance 2018-06-01 00:00:00  20180601000000  7544.90  7699.00
# 1    BTCUSDT:binance 2018-06-01 04:00:00  20180601040000  7485.01  7575.00
# 2    BTCUSDT:binance 2018-06-01 08:00:00  20180601080000  7495.13  7538.00
# 3    BTCUSDT:binance 2018-06-01 12:00:00  20180601120000  7572.09  7608.55
# 4    BTCUSDT:binance 2018-06-01 16:00:00  20180601160000  7361.39  7599.99
# 5    BTCUSDT:binance 2018-06-01 20:00:00  20180601200000  7447.30  7461.06
# 6    BTCUSDT:binance 2018-06-02 00:00:00  20180602000000  7440.14  7461.08
# 7    BTCUSDT:binance 2018-06-02 04:00:00  20180602040000  7521.01  7540.00
# 8    BTCUSDT:binance 2018-06-02 08:00:00  20180602080000  7500.00  7533.00
# 9    BTCUSDT:binance 2018-06-02 12:00:00  20180602120000  7641.00  7685.00
# 10   BTCUSDT:binance 2018-06-02 16:00:00  20180602160000  7652.28  7695.17
# 11   BTCUSDT:binance 2018-06-02 20:00:00  20180602200000  7623.10  7697.33
# 12   BTCUSDT:binance 2018-06-03 00:00:00  20180603000000  7665.00  7672.00
# 13   BTCUSDT:binance 2018-06-03 04:00:00  20180603040000  7640.03  7672.00
# 14   BTCUSDT:binance 2018-06-03 08:00:00  20180603080000  7643.10  7676.12
# 15   BTCUSDT:binance 2018-06-03 12:00:00  20180603120000  7720.00  7786.69
# 16   BTCUSDT:binance 2018-06-03 16:00:00  20180603160000  7714.85  7776.25
# 17   BTCUSDT:binance 2018-06-03 20:00:00  20180603200000  7730.01  7750.26
# 18   BTCUSDT:binance 2018-06-04 00:00:00  20180604000000  7699.57  7739.97
# 19   BTCUSDT:binance 2018-06-04 04:00:00  20180604040000  7714.26  7729.00
# 20   BTCUSDT:binance 2018-06-04 08:00:00  20180604080000  7690.00  7760.52
# 21   BTCUSDT:binance 2018-06-04 12:00:00  20180604120000  7597.70  7707.00
# 22   BTCUSDT:binance 2018-06-04 16:00:00  20180604160000  7505.00  7628.98
# 23   BTCUSDT:binance 2018-06-04 20:00:00  20180604200000  7496.99  7538.99
# 24   BTCUSDT:binance 2018-06-05 00:00:00  20180605000000  7494.99  7515.00
# 25   BTCUSDT:binance 2018-06-05 04:00:00  20180605040000  7487.00  7548.82
# 26   BTCUSDT:binance 2018-06-05 08:00:00  20180605080000  7417.36  7518.80
# 27   BTCUSDT:binance 2018-06-05 12:00:00  20180605120000  7412.01  7455.94
# 28   BTCUSDT:binance 2018-06-05 16:00:00  20180605160000  7428.88  7470.00
# 29   BTCUSDT:binance 2018-06-05 20:00:00  20180605200000  7577.09  7594.00
# ..               ...                 ...             ...      ...      ...
# 17   7680.06  7714.85   4429.310377
# 18   7636.21  7731.00   5393.804494
# 19   7672.36  7699.58   4216.279321
# 20   7665.32  7714.26   4411.220582
# 21   7568.00  7688.99   6223.270341
# 22   7484.25  7597.70   7312.846478
# 23   7446.50  7505.00   5395.244612
# 24   7447.00  7496.99   4825.258593
# 25   7459.00  7494.99   4090.994509
# 26   7376.21  7487.00   5090.941305
# 27   7367.83  7417.36   4866.471468
# 28   7386.70  7412.01   4988.372156
# 29   7358.00  7422.10   5458.911206
# ..       ...      ...           ...
# 648  6409.74  6482.00   4850.648671
# 649  6477.22  6505.73   3631.529027
# 650  6500.00  6500.08   3138.571759
# 651  6460.00  6517.17   2557.206643
# 652  6417.51  6480.03   5080.764350
# 653  6225.00  6473.05  12024.948317
# 654  6243.08  6262.10   7156.582470
# 655  6201.00  6269.99   6029.181199
# 656  6224.98  6248.69   4341.963671
# 657  6232.17  6237.55   4899.858347
# 658  6234.44  6292.94   4339.905628
# 659  6267.00  6287.65   8145.794781
# 660  6285.51  6360.01   6124.807803
# 661  6280.00  6301.90   4768.536440
# 662  6305.00  6336.39   4540.013360
# 663  6327.00  6362.58   3411.337152
# 664  6257.29  6356.94   5727.219766
# 665  6252.17  6286.42   4529.425402
# 666  6123.00  6330.67  14980.656335
# 667  6366.00  6412.14   5855.428067
# 668  6374.99  6392.00   5128.943936
# 669  6382.54  6397.29   1787.028590
# 670  6375.61  6411.00   2080.999734
# 671  6394.00  6425.03   3500.625798
# 672  6390.00  6417.77   2668.268761
# 673  6325.00  6421.99  10023.157909
# 674  6491.00  6492.00   6052.322172
# 675  6522.11  6554.67   7537.449784
# 676  6647.91  6647.91  10700.428240
# 677  6666.00  6742.23  10855.883723
#
# [678 rows x 8 columns]

# %%
dv = HFDataView()
dv.create_init_dv(Time_dict.set_index(["trade_date","symbol"]))
# Out:
# Initialize dataview success.

# %% [markdown]
# 编写绘图函数

# %%
def plot_1(close,alpha,M):
    '''
    绘制图像
    '''
    fig,(ax,ax1) = plt.subplots(2,1,sharex=True, figsize=(15,8))
    ax.grid(axis='both')
    ax.xaxis.set_major_locator(plt.MultipleLocator(1))
    ax.yaxis.set_major_locator(plt.MultipleLocator(500))
    ax1.grid()
    ax1.xaxis.set_major_locator(plt.MultipleLocator(1))
    ax1.yaxis.set_major_locator(plt.MultipleLocator(M))
    ax.plot(close)
    ax1.plot(alpha)
    plt.show()

# %%
def rank_hang(df):
    return df.rank(axis= 1, pct=True)

# %%
dv.add_formula("close_ret", "Return(close,1)", add_data=True)
# Out:
# symbol          BTCUSDT:binance
# trade_date
# 20180601000000              NaN
# 20180601040000        -0.007938
# 20180601080000         0.001352
# 20180601120000         0.010268
# 20180601160000        -0.027826
# 20180601200000         0.011670
# 20180602000000        -0.000961
# 20180602040000         0.010869
# 20180602080000        -0.002794
# 20180602120000         0.018800
# 20180602160000         0.001476
# 20180602200000        -0.003813
# 20180603000000         0.005496
# 20180603040000        -0.003258
# 20180603080000         0.000402
# 20180603120000         0.010061
# 20180603160000        -0.000667
# 20180603200000         0.001965
# 20180604000000        -0.003938
# 20180604040000         0.001908
# 20180604080000        -0.003145
# 20180604120000        -0.012003
# 20180604160000        -0.012201
# 20180604200000        -0.001067
# 20180605000000        -0.000267
# 20180605040000        -0.001066
# 20180605080000        -0.009301
# 20180605120000        -0.000721
# 20180605160000         0.002276
# 20180605200000         0.019951
# ...                         ...
# 20180917000000         0.003664
# 20180917040000        -0.000115
# 20180917080000         0.001869
# 20180917120000        -0.005700
# 20180917160000        -0.000628
# 20180917200000        -0.032564
# 20180918000000         0.000789
# 20180918040000        -0.003399
# 20180918080000        -0.001592
# 20180918120000         0.008240
# 20180918160000        -0.000397
# 20180918200000         0.011508
# 20180919000000        -0.009121
# 20180919040000         0.005467
# 20180919080000         0.004364
# 20180919120000        -0.001123
# 20180919160000        -0.011095
# 20180919200000         0.006606
# 20180920000000         0.012998
# 20180920040000        -0.002856
# 20180920080000         0.000845
# 20180920120000         0.002143
# 20180920160000         0.002633
# 20180920200000        -0.001549
# 20180921000000         0.000326
# 20180921040000         0.011213
# 20180921080000         0.009658
# 20180921120000         0.014220
# 20180921160000         0.014188
# 20180921200000        -0.008789
#
# [678 rows x 1 columns]

# %%
dv

# %% [markdown]
# 主要考虑两个指标，Sharp Ratio和技术指标：心理线

# %%
# Sharp Ratio比率
SharpeRatio20 = dv.add_formula('SharpeRatio20_J', "(Ts_Mean(close_ret,20)*250-0.03)/StdDev(close_ret,20)/Sqrt(250)",add_data=True)
alpha2_plot = dv.get_ts('SharpeRatio20_J', date_type='datetime')
close = dv.get_ts('close', date_type='datetime')
print('此指标代表20日夏普比率，通过获得的超额收益除以策略波动率得出，主要衡量每单位风险承担的超额收益。\n'
      '现象：本指标往往处于-8到8之间，当指标在低点时超额收益低，可以作为买入信号，指标处于高点时，收益率较高，可以作为卖出信号')
plot_1(close, alpha2_plot,1)
# Out:
# 此指标代表20日夏普比率，通过获得的超额收益除以策略波动率得出，主要衡量每单位风险承担的超额收益。
# 现象：本指标往往处于-8到8之间，当指标在低点时超额收益低，可以作为买入信号，指标处于高点时，收益率较高，可以作为卖出信号

# %% [markdown]
# 从图中可以看出，20日夏普比率效果还可以，当触及异常值时往往意味着反转的信号，可以作为信号同一些趋势因子（如MA10，MA20等）结合使用

# %%
# 心理线
psy_j = dv.add_formula("psy_j", "Ts_Sum(close>Delay(close,1),12)/12*100", add_data=True)
alpha1_plot = dv.get_ts('psy_j', date_type='datetime')
open = dv.get_ts('open', date_type='datetime')
close = dv.get_ts('close', date_type='datetime')
print('PSY，俗称心理线指标，研究投资者的情绪波动指标，投资者的情绪往往会反应市场的情绪，可以看出市场对行情的反应，短期内可能会有一定的持续效应，但是长期可能存在反转效应。\n'
      '现象：通常指标在25到75之间波动，当价格下跌时，psy指标往往随之下跌，在25以下往往处于超卖阶段，市场情绪非理性波动，可以考虑买入；当标的价格下跌到一定程度时，psy随之上涨，75以上处于超买区，适合卖出')
plot_1(open, alpha1_plot,5)
# Out:
# PSY，俗称心理线指标，研究投资者的情绪波动指标，投资者的情绪往往会反应市场的情绪，可以看出市场对行情的反应，短期内可能会有一定的持续效应，但是长期可能存在反转效应。
# 现象：通常指标在25到75之间波动，当价格下跌时，psy指标往往随之下跌，在25以下往往处于超卖阶段，市场情绪非理性波动，可以考虑买入；当标的价格下跌到一定程度时，psy随之上涨，75以上处于超买区，适合卖出

# %% [markdown]
# 从心理线图中可以看出，心理线更适合做短期指标，周期性较强，不适合在趋势下使用，适合作为反转信号，或者做成一个事件因子使用
